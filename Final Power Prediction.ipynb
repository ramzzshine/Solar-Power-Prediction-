# %%
#Loading libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading Dataset

# %%
Power = pd.read_csv("power_actual.csv")
Power.head()
# Out:
#    Unnamed: 0             datetime  ghi  gti  power
# 0           0  2017-10-01 00:00:00  0.0  0.0    0.0
# 1           1  2017-10-01 00:15:00  0.0  0.0    0.0
# 2           2  2017-10-01 00:30:00  0.0  0.0    0.0
# 3           3  2017-10-01 00:45:00  0.0  0.0    0.0
# 4           4  2017-10-01 01:00:00  0.0  0.0    0.0

# %%
Power.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70080 entries, 0 to 70079
# Data columns (total 5 columns):
# Unnamed: 0    70080 non-null int64
# datetime      70080 non-null object
# ghi           35040 non-null float64
# gti           35040 non-null float64
# power         70080 non-null float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 2.7+ MB

# %%
Actual_weather = pd.read_csv("weather_actuals.csv")
Actual_weather.head()
# Out:
#    Unnamed: 0  plant_id         datetime_utc       datetime_local  \
# 0           0         1  2017-09-30 18:30:00  2017-10-01 00:00:00
# 1           1         1  2017-09-30 19:30:00  2017-10-01 01:00:00
# 2           2         1  2017-09-30 20:30:00  2017-10-01 02:00:00
# 3           3         1  2017-09-30 21:30:00  2017-10-01 03:00:00
# 4           4         1  2017-09-30 22:30:00  2017-10-01 04:00:00
#
#    cloud_cover  apparent_temperature  temperature  humidity  dew_point  \
# 0          0.0                 26.52           26         1      19.46
# 1          0.0                 28.78           27         1      20.06
# 2          0.0                 26.58           26         1      19.97
# 3          0.0                 23.84           23         1      18.66
# 4          0.0                 24.13           24         1      17.84
#
#    wind_bearing  ...  precip_accumulation  precip_intensity  \
# 0           308  ...              -9999.0           -9999.0
# ...

# %%
Forecast_weather = pd.read_csv("weather_forecast.csv")
Forecast_weather.head()
# Out:
#    Unnamed: 0  plant_id         datetime_utc       datetime_local  \
# 0           0         1  2019-09-30 18:30:00  2019-10-01 00:00:00
# 1           1         1  2019-09-30 19:30:00  2019-10-01 01:00:00
# 2           2         1  2019-09-30 20:30:00  2019-10-01 02:00:00
# 3           3         1  2019-09-30 21:30:00  2019-10-01 03:00:00
# 4           4         1  2019-09-30 22:30:00  2019-10-01 04:00:00
#
#    cloud_cover  apparent_temperature  temperature  humidity  dew_point  \
# 0         0.35                 26.41           26         1      22.01
# 1         0.43                 25.95           25         1      22.06
# 2         0.48                 25.46           25         1      22.06
# 3         0.49                 24.80           24         1      21.87
# 4         0.49                 23.99           23         1      21.53
#
#    wind_bearing  ...  precip_accumulation  precip_intensity  \
# 0           101  ...                  NaN               0.0
# ...

# %%
Actual_weather.shape
# Out:
# (13619, 31)

# %%
Actual_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13619 entries, 0 to 13618
# Data columns (total 31 columns):
# Unnamed: 0              13619 non-null int64
# plant_id                13619 non-null int64
# datetime_utc            13619 non-null object
# datetime_local          13619 non-null object
# cloud_cover             13619 non-null float64
# apparent_temperature    13619 non-null float64
# temperature             13619 non-null int64
# humidity                13619 non-null int64
# dew_point               13619 non-null float64
# wind_bearing            13619 non-null int64
# wind_speed              13619 non-null float64
# wind_chill              3744 non-null float64
# wind_gust               13619 non-null float64
# heat_index              3744 non-null float64
# pressure                13619 non-null float64
# qpf                     3744 non-null float64
# uv_index                13619 non-null int64
# snow                    3744 non-null float64
# ...

# %%
Forecast_weather.shape
# Out:
# (648, 31)

# %%
Forecast_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 648 entries, 0 to 647
# Data columns (total 31 columns):
# Unnamed: 0              648 non-null int64
# plant_id                648 non-null int64
# datetime_utc            648 non-null object
# datetime_local          648 non-null object
# cloud_cover             648 non-null float64
# apparent_temperature    648 non-null float64
# temperature             648 non-null int64
# humidity                648 non-null int64
# dew_point               648 non-null float64
# wind_bearing            648 non-null int64
# wind_speed              648 non-null float64
# wind_chill              0 non-null float64
# wind_gust               648 non-null float64
# heat_index              0 non-null float64
# pressure                648 non-null float64
# qpf                     0 non-null float64
# uv_index                648 non-null int64
# snow                    0 non-null float64
# pop                     0 non-null float64
# ...

# %% [markdown]
# If we have observed above data types maximum there are float datatype and the features in both Actual_weather and Forecast_weather are same.

# %% [markdown]
# # Data Description

# %% [markdown]
# There are 3 data sets Provided.
# 1. Power_Actual : In this 4 Features are given - datetime, power, Global Horizontal Irradiance & Global Tilt Irradiance.
# 2. Actual Weather : It gives info about the weather indices like precipitation, heat, snow, pressure, wind, UV_rays, Ozone, temperature, climatic conditions wrt date & time. This dataset is taken from time period of Oct 1st 2017 to sep 30th 2019
# 3. Forecast Weather : The data set have similar features of Actual Weather. This dataset is taken from time period of Oct 1st 2019 to Oct 27th 2019.

# %% [markdown]
# # Null Handling

# %%
#checking the missing data in the given dataset
total = Power.isnull().sum().sort_values(ascending=False)
percent = (Power.isnull().sum()/Power.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(25)
# Out:
#             Total  Percent
# gti         35040      0.5
# ghi         35040      0.5
# power           0      0.0
# datetime        0      0.0
# Unnamed: 0      0      0.0

# %%
Power.nunique()
# Out:
# Unnamed: 0    70080
# datetime      70080
# ghi               1
# gti               1
# power          2171
# dtype: int64

# %%
columns = Power.columns.tolist()
for i in columns:
    print(i)
    print(Power[i].unique())
# Out:
# Unnamed: 0
# [    0     1     2 ... 70077 70078 70079]
# datetime
# ['2017-10-01 00:00:00' '2017-10-01 00:15:00' '2017-10-01 00:30:00' ...
#  '2019-09-30 23:15:00' '2019-09-30 23:30:00' '2019-09-30 23:45:00']
# ghi
# [ 0. nan]
# gti
# [ 0. nan]
# power
# [0.00000e+00 8.00000e-02 3.40000e-01 ... 5.60224e+03 3.92693e+03
#  2.61160e+03]

# %% [markdown]
# As the ghi & gti has only 1 unique value we are dropping them

# %%
#Dropping the above mentioned columns,
Power = Power.drop(['ghi','gti','Unnamed: 0'],axis=1)

# %%
Power.head()
# Out:
#               datetime  power
# 0  2017-10-01 00:00:00    0.0
# 1  2017-10-01 00:15:00    0.0
# 2  2017-10-01 00:30:00    0.0
# 3  2017-10-01 00:45:00    0.0
# 4  2017-10-01 01:00:00    0.0

# %%
#checking the missing data in the given dataset
total = Actual_weather.isnull().sum().sort_values(ascending=False)
percent = (Actual_weather.isnull().sum()/Actual_weather.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(25)
# Out:
#                       Total  Percent
# qpf                    9875  0.72509
# wind_chill             9875  0.72509
# snow                   9875  0.72509
# pop                    9875  0.72509
# fctcode                9875  0.72509
# precip_accumulation    9875  0.72509
# heat_index             9875  0.72509
# precip_type            7129  0.52346
# apparent_temperature      0  0.00000
# temperature               0  0.00000
# cloud_cover               0  0.00000
# humidity                  0  0.00000
# datetime_local            0  0.00000
# datetime_utc              0  0.00000
# plant_id                  0  0.00000
# dew_point                 0  0.00000
# wind_bearing              0  0.00000
# wind_speed                0  0.00000
# updated_at                0  0.00000
# wind_gust                 0  0.00000
# pressure                  0  0.00000
# summary                   0  0.00000
# uv_index                  0  0.00000
# ozone                     0  0.00000
# ...

# %%
columns =Actual_weather.columns.tolist()
for i in columns:
    print(i)
    print(Actual_weather[i].unique())
    print('\n')
# Out:
# Unnamed: 0
# [    0     1     2 ... 13616 13617 13618]
#
#
# plant_id
# [1]
#
#
# datetime_utc
# ['2017-09-30 18:30:00' '2017-09-30 19:30:00' '2017-09-30 20:30:00' ...
#  '2019-09-30 15:30:00' '2019-09-30 16:30:00' '2019-09-30 17:30:00']
#
#
# datetime_local
# ['2017-10-01 00:00:00' '2017-10-01 01:00:00' '2017-10-01 02:00:00' ...
#  '2019-09-30 21:00:00' '2019-09-30 22:00:00' '2019-09-30 23:00:00']
#
#
# cloud_cover
# [ 0.000e+00  9.000e-02  1.400e-01  1.500e-01 -9.999e+03  3.100e-01
#   2.500e-01  3.500e-01  2.000e-01  2.400e-01  1.000e-01  2.300e-01
#   1.600e-01  1.900e-01  5.800e-01  2.600e-01  3.300e-01  2.200e-01
#   2.700e-01  3.000e-02  5.500e-01  1.800e-01  8.000e-02  3.200e-01
#   2.900e-01  2.800e-01  5.100e-01  6.300e-01  5.400e-01  7.000e-02
#   6.400e-01  6.800e-01  6.700e-01  6.000e-02  9.100e-01  7.900e-01
#   5.300e-01  3.800e-01  1.200e-01  2.100e-01  4.700e-01  1.300e-01
#   4.000e-02  5.000e-02  1.700e-01  6.200e-01  6.000e-01  6.500e-01
# ...

# %%
#checking the missing data in the given dataset
total = Forecast_weather.isnull().sum().sort_values(ascending=False)
percent = (Forecast_weather.isnull().sum()/Forecast_weather.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(25)
# Out:
#                       Total   Percent
# qpf                     648  1.000000
# wind_chill              648  1.000000
# snow                    648  1.000000
# pop                     648  1.000000
# fctcode                 648  1.000000
# precip_accumulation     648  1.000000
# heat_index              648  1.000000
# precip_type             534  0.824074
# apparent_temperature      0  0.000000
# temperature               0  0.000000
# cloud_cover               0  0.000000
# humidity                  0  0.000000
# datetime_local            0  0.000000
# datetime_utc              0  0.000000
# plant_id                  0  0.000000
# dew_point                 0  0.000000
# wind_bearing              0  0.000000
# wind_speed                0  0.000000
# updated_at                0  0.000000
# wind_gust                 0  0.000000
# pressure                  0  0.000000
# summary                   0  0.000000
# uv_index                  0  0.000000
# ozone                     0  0.000000
# ...

# %% [markdown]
# # Dropping Null values

# %% [markdown]
# Now we are dropping in which null values are more than which have only 1 unique value and other is nan. so that we cant find them in null values.

# %%
Actual_weather.drop(['plant_id','precip_type','precip_accumulation','heat_index','qpf','snow','pop','fctcode','wind_chill'],axis=1, inplace=True)

# %%
Forecast_weather.drop(['plant_id','precip_type','precip_accumulation','heat_index','qpf','snow','pop','fctcode','wind_chill'],axis=1, inplace=True)

# %%
Actual_weather.drop(['Unnamed: 0','updated_at','summary'],axis=1, inplace=True)

# %%
Forecast_weather.drop(['Unnamed: 0','updated_at','summary'],axis=1, inplace=True)

# %% [markdown]
# # Merging Actual_weather & Actual_Power data

# %% [markdown]
# If we observe we can find the datetime in Actual_power & datetime_local in Actual_weather data are same. so we are joining datasets on these two features.

# %%
train_data = pd.merge(Power , Actual_weather,  how='inner', left_on=['datetime'], right_on = ['datetime_local'])

# %%
train_data.head()
# Out:
#               datetime  power         datetime_utc       datetime_local  \
# 0  2017-10-01 00:00:00    0.0  2017-09-30 18:30:00  2017-10-01 00:00:00
# 1  2017-10-01 01:00:00    0.0  2017-09-30 19:30:00  2017-10-01 01:00:00
# 2  2017-10-01 02:00:00    0.0  2017-09-30 20:30:00  2017-10-01 02:00:00
# 3  2017-10-01 03:00:00    0.0  2017-09-30 21:30:00  2017-10-01 03:00:00
# 4  2017-10-01 04:00:00    0.0  2017-09-30 22:30:00  2017-10-01 04:00:00
#
#    cloud_cover  apparent_temperature  temperature  humidity  dew_point  \
# 0          0.0                 26.52           26         1      19.46
# 1          0.0                 28.78           27         1      20.06
# 2          0.0                 26.58           26         1      19.97
# 3          0.0                 23.84           23         1      18.66
# 4          0.0                 24.13           24         1      17.84
#
#    wind_bearing  ...  wind_gust  pressure  uv_index   ozone  precip_intensity  \
# ...

# %% [markdown]
# ## Null value Handling

# %%
train_data.isnull().sum()
# Out:
# datetime                0
# power                   0
# datetime_utc            0
# datetime_local          0
# cloud_cover             0
# apparent_temperature    0
# temperature             0
# humidity                0
# dew_point               0
# wind_bearing            0
# wind_speed              0
# wind_gust               0
# pressure                0
# uv_index                0
# ozone                   0
# precip_intensity        0
# precip_probability      0
# visibility              0
# sunrise                 0
# sunset                  0
# icon                    0
# dtype: int64

# %%
train_data.shape
# Out:
# (13619, 21)

# %%
train_data.columns
# Out:
# Index(['datetime', 'power', 'datetime_utc', 'datetime_local', 'cloud_cover',
#        'apparent_temperature', 'temperature', 'humidity', 'dew_point',
#        'wind_bearing', 'wind_speed', 'wind_gust', 'pressure', 'uv_index',
#        'ozone', 'precip_intensity', 'precip_probability', 'visibility',
#        'sunrise', 'sunset', 'icon'],
#       dtype='object')

# %% [markdown]
# we have to utilize any one timezone. if we take all the analysis will be bombarded and confuded. so i am taking Universal datetime i.e datetime_utc

# %%
train_data.drop(['datetime','datetime_local'],axis=1, inplace=True)

# %%
train_data.shape
# Out:
# (13619, 19)

# %% [markdown]
# ## Feature engineering

# %%
train_data[['apparent_temperature','temperature']].head()
# Out:
#    apparent_temperature  temperature
# 0                 26.52           26
# 1                 28.78           27
# 2                 26.58           26
# 3                 23.84           23
# 4                 24.13           24

# %% [markdown]
# If we obseve both apparent_temp & temperature are having approximately same values ao we i am going with temperature as it is not a float datatype.

# %%
train_data.drop(['apparent_temperature'],axis=1, inplace=True)

# %%
train_data.columns
# Out:
# Index(['power', 'datetime_utc', 'cloud_cover', 'temperature', 'humidity',
#        'dew_point', 'wind_bearing', 'wind_speed', 'wind_gust', 'pressure',
#        'uv_index', 'ozone', 'precip_intensity', 'precip_probability',
#        'visibility', 'sunrise', 'sunset', 'icon'],
#       dtype='object')

# %%
train_data.describe()
# Out:
#               power   cloud_cover   temperature      humidity     dew_point  \
# count  13619.000000  13619.000000  13619.000000  13619.000000  13619.000000
# mean      35.255627   -314.005310     24.498054      0.537411     11.924626
# std      557.059759   1744.610028      8.840016      0.498617      9.129459
# min        0.000000  -9999.000000      5.000000      0.000000    -20.560000
# 25%        0.000000      0.000000     17.000000      0.000000      5.920000
# 50%        0.000000      0.000000     25.000000      1.000000     10.710000
# 75%        5.810000      0.410000     31.000000      1.000000     19.670000
# max    15504.750000      1.000000     47.000000      1.000000     28.350000
#
#        wind_bearing    wind_speed     wind_gust      pressure      uv_index  \
# count  13619.000000  13619.000000  13619.000000  13619.000000  13619.000000
# mean    -498.677363   -540.808704  -2393.184251   -733.594065  -2394.989280
# ...

# %%
train_data.dtypes
# Out:
# power                 float64
# datetime_utc           object
# cloud_cover           float64
# temperature             int64
# humidity                int64
# dew_point             float64
# wind_bearing            int64
# wind_speed            float64
# wind_gust             float64
# pressure              float64
# uv_index                int64
# ozone                 float64
# precip_intensity      float64
# precip_probability    float64
# visibility            float64
# sunrise                object
# sunset                 object
# icon                   object
# dtype: object

# %% [markdown]
# # Formatting Datetime

# %%
train_data[['datetime_utc','sunrise','sunset']].head()
# Out:
#           datetime_utc              sunrise               sunset
# 0  2017-09-30 18:30:00  2017-10-01 00:52:02  2017-10-01 12:45:07
# 1  2017-09-30 19:30:00  2017-10-01 00:52:02  2017-10-01 12:45:07
# 2  2017-09-30 20:30:00  2017-10-01 00:52:02  2017-10-01 12:45:07
# 3  2017-09-30 21:30:00  2017-10-01 00:52:02  2017-10-01 12:45:07
# 4  2017-09-30 22:30:00  2017-10-01 00:52:02  2017-10-01 12:45:07

# %%
train_data['datetime_utc'] = train_data['datetime_utc'].astype(str)
train_data['sunrise'] = train_data['sunrise'].astype(str)
train_data['sunset'] = train_data['sunset'].astype(str)

# %%
train_data['datetime_utc'] = pd.to_datetime(train_data['datetime_utc'],dayfirst=True)

# %%
train_data['sunrise'] = pd.to_datetime(train_data['sunrise'],dayfirst=True)

# %%
train_data['sunset'] = pd.to_datetime(train_data['sunset'],dayfirst=True)

# %%
train_data[['datetime_utc','sunrise','sunset']].head()
# Out:
#          datetime_utc             sunrise              sunset
# 0 2017-09-30 18:30:00 2017-10-01 00:52:02 2017-10-01 12:45:07
# 1 2017-09-30 19:30:00 2017-10-01 00:52:02 2017-10-01 12:45:07
# 2 2017-09-30 20:30:00 2017-10-01 00:52:02 2017-10-01 12:45:07
# 3 2017-09-30 21:30:00 2017-10-01 00:52:02 2017-10-01 12:45:07
# 4 2017-09-30 22:30:00 2017-10-01 00:52:02 2017-10-01 12:45:07

# %%
Forecast_weather['datetime_utc'] = Forecast_weather['datetime_utc'].astype(str)
Forecast_weather['datetime_utc'] = pd.to_datetime(Forecast_weather['datetime_utc'],dayfirst=True)
Forecast_weather['sunrise'] = Forecast_weather['sunrise'].astype(str)
Forecast_weather['sunrise'] = pd.to_datetime(Forecast_weather['sunrise'],dayfirst=True)
Forecast_weather['sunset'] = Forecast_weather['sunset'].astype(str)
Forecast_weather['sunset'] = pd.to_datetime(Forecast_weather['sunset'],dayfirst=True)

# %%
Forecast_weather[['datetime_utc','sunrise','sunset']].head()
# Out:
#          datetime_utc             sunrise              sunset
# 0 2019-09-30 18:30:00 2019-10-01 00:51:47 2019-10-01 12:45:42
# 1 2019-09-30 19:30:00 2019-10-01 00:51:47 2019-10-01 12:45:42
# 2 2019-09-30 20:30:00 2019-10-01 00:51:47 2019-10-01 12:45:42
# 3 2019-09-30 21:30:00 2019-10-01 00:51:47 2019-10-01 12:45:42
# 4 2019-09-30 22:30:00 2019-10-01 00:51:47 2019-10-01 12:45:42

# %% [markdown]
# If we observe above datetime we can find minutes and seconds are constant so we are extracting the hours column for respective date as a seperate column. so that it will be easy for us to calculate how many hours we are getting sunlight per day & how much power we can generate perday.

# %%
train_data['dtUTC_hour'] = train_data['datetime_utc'].dt.hour

# %%
train_data[['dtUTC_hour','datetime_utc']].head()
# Out:
#    dtUTC_hour        datetime_utc
# 0          18 2017-09-30 18:30:00
# 1          19 2017-09-30 19:30:00
# 2          20 2017-09-30 20:30:00
# 3          21 2017-09-30 21:30:00
# 4          22 2017-09-30 22:30:00

# %%
train_data['SR_hour'] = train_data['sunrise'].dt.hour

# %%
train_data['SS_hour'] = train_data['sunset'].dt.hour

# %%
Forecast_weather['dtUTC_hour'] = Forecast_weather['datetime_utc'].dt.hour
Forecast_weather['SR_hour'] = Forecast_weather['sunrise'].dt.hour
Forecast_weather['SS_hour'] = Forecast_weather['sunset'].dt.hour

# %%
train_data[['dtUTC_hour','SR_hour','SS_hour']].head()
# Out:
#    dtUTC_hour  SR_hour  SS_hour
# 0          18        0       12
# 1          19        0       12
# 2          20        0       12
# 3          21        0       12
# 4          22        0       12

# %%
Forecast_weather[['dtUTC_hour','SR_hour','SS_hour']].head()
# Out:
#    dtUTC_hour  SR_hour  SS_hour
# 0          18        0       12
# 1          19        0       12
# 2          20        0       12
# 3          21        0       12
# 4          22        0       12

# %%
train_data['sunlight_hours']= train_data['SS_hour'] - train_data['SR_hour']
train_data['sunlight_hours'].head()
# Out:
# 0    12
# 1    12
# 2    12
# 3    12
# 4    12
# Name: sunlight_hours, dtype: int64

# %%
Forecast_weather['sunlight_hours']= Forecast_weather['SS_hour'] - Forecast_weather['SR_hour']
Forecast_weather['sunlight_hours'].head()
# Out:
# 0    12
# 1    12
# 2    12
# 3    12
# 4    12
# Name: sunlight_hours, dtype: int64

# %%
train_data['exposure_duration'] = train_data['dtUTC_hour'] -  train_data['SR_hour']
train_data['exposure_duration'].head()
# Out:
# 0    18
# 1    19
# 2    20
# 3    21
# 4    22
# Name: exposure_duration, dtype: int64

# %%
Forecast_weather['exposure_duration'] = Forecast_weather['dtUTC_hour'] -  Forecast_weather['SR_hour']
Forecast_weather['exposure_duration'].head()
# Out:
# 0    18
# 1    19
# 2    20
# 3    21
# 4    22
# Name: exposure_duration, dtype: int64

# %% [markdown]
#  Now dropping the date time columns because we extracted the required information out of these columns ,
# i.e the hour factor

# %%
train_data.drop(['sunrise','sunset'] ,axis=1 , inplace=True)

# %%
train_data.drop(['datetime_utc'] ,axis=1 , inplace=True)

# %%
train_data.shape
# Out:
# (13619, 20)

# %%
Forecast_weather.shape
# Out:
# (648, 24)

# %%
Forecast_weather.drop(['datetime_local','datetime_utc','sunrise','sunset'] ,axis=1 , inplace=True)

# %%
Forecast_weather.drop(['temperature'] ,axis=1 , inplace=True)

# %%
Forecast_weather.shape
# Out:
# (648, 19)

# %%
train_data.columns
# Out:
# Index(['power', 'cloud_cover', 'temperature', 'humidity', 'dew_point',
#        'wind_bearing', 'wind_speed', 'wind_gust', 'pressure', 'uv_index',
#        'ozone', 'precip_intensity', 'precip_probability', 'visibility', 'icon',
#        'dtUTC_hour', 'SR_hour', 'SS_hour', 'sunlight_hours',
#        'exposure_duration'],
#       dtype='object')

# %% [markdown]
# # Removing Outliers

# %%
sns.distplot(train_data['power'], hist= True)

# %%
plt.show()

# %%
pd.get_dummies(train_data)
# Out:
#        power  cloud_cover  temperature  humidity  dew_point  wind_bearing  \
# 0        0.0         0.00           26         1      19.46           308
# 1        0.0         0.00           27         1      20.06         -9999
# 2        0.0         0.00           26         1      19.97         -9999
# 3        0.0         0.00           23         1      18.66           270
# 4        0.0         0.00           24         1      17.84         -9999
# ...      ...          ...          ...       ...        ...           ...
# 13614    0.0         0.16           29         1      21.19            40
# 13615    0.0         0.16           28         1      21.35            59
# 13616    0.0         0.18           27         1      21.61            76
# 13617    0.0         0.30           27         1      21.99            88
# 13618    0.0         0.35           26         1      22.09            95
#
#        wind_speed  wind_gust  pressure  uv_index  ...  sunlight_hours  \
# ...

# %%
train_data.power.describe(percentiles=[0.75,0.80,0.85,0.90,0.95,0.99,0.992,0.994,0.996,0.998,0.999])
# Out:
# count    13619.000000
# mean        35.255627
# std        557.059759
# min          0.000000
# 50%          0.000000
# 75%          5.810000
# 80%          8.310000
# 85%         10.650000
# 90%         12.470000
# 95%         14.001000
# 99%         16.168200
# 99.2%       16.610560
# 99.4%       17.145840
# 99.6%     1823.596160
# 99.8%     7590.228120
# 99.9%    11044.371300
# max      15504.750000
# Name: power, dtype: float64

# %%
train_data.loc[(train_data['power'] >= 5.81)]
# Out:
#        power  cloud_cover  temperature  humidity  dew_point  wind_bearing  \
# 9       7.04         0.00           26         1      17.33           237
# 10     10.08         0.00           31         0      18.09           281
# 11     12.09         0.00           32         0      17.72           278
# 12     13.16         0.00           36         0      16.43           304
# 13     12.42         0.00           36         0      15.56           291
# ...      ...          ...          ...       ...        ...           ...
# 13539   6.28         0.13           34         0      21.45            73
# 13580   8.15         0.08           26         1      23.49           111
# 13581   9.32         0.08           26         1      23.54            89
# 13584  14.65         0.13           28         1      22.44            64
# 13586  10.36         0.17           30         1      21.54            70
#
#        wind_speed  wind_gust  pressure  uv_index   ozone  precip_intensity  \
# ...

# %%
plt.boxplot(train_data.power)
Q1 = train_data.power.quantile(0.00)
Q3 = train_data.power.quantile(0.99)
IQR = Q3 - Q1
train_data = train_data[(train_data.power >= Q1 ) & (train_data.power <= Q3 )]

# %%
sns.distplot(train_data['power'], hist= True)

# %%
plt.show()

# %% [markdown]
# If we obsevere above 2 plots in Removing outliers section. We can see the difference in plot before reducing outliers and after reducing outliers.

# %%
plt.figure(figsize=(20,15))
sns.heatmap(train_data.corr(),cmap='YlGnBu',annot=True)
plt.show()

# %% [markdown]
# This shows  that our target variable ‘power’ somewhat strongly correlates with ‘apparent_temperature

# %%
train_data.dtypes
# Out:
# power                 float64
# cloud_cover           float64
# temperature             int64
# humidity                int64
# dew_point             float64
# wind_bearing            int64
# wind_speed            float64
# wind_gust             float64
# pressure              float64
# uv_index                int64
# ozone                 float64
# precip_intensity      float64
# precip_probability    float64
# visibility            float64
# icon                   object
# dtUTC_hour              int64
# SR_hour                 int64
# SS_hour                 int64
# sunlight_hours          int64
# exposure_duration       int64
# dtype: object

# %%
plt.figure(figsize=(30,15))
plt.subplot(4,4,1)
plt.scatter(train_data['exposure_duration'] , train_data['power'],c='g')
plt.xlabel("exposure_duration",fontsize=10)
plt.ylabel("Power",fontsize=10)                                                        

plt.subplot(4,4,2)
plt.scatter(train_data['sunlight_hours'] , train_data['power'],c='b')
plt.xlabel("sunlight_hours",fontsize=10)
plt.ylabel("Power",fontsize=10)


plt.subplot(4,4,3)
plt.scatter(train_data['cloud_cover'] , train_data['power'] , c='y')
plt.xlabel('cloud_cover',fontsize=10)
plt.ylabel("Power",fontsize=10)

plt.subplot(4,4,4)
plt.scatter(train_data['temperature'] , train_data['power'], c='c')
plt.xlabel("temperature",fontsize=10)
plt.ylabel("Power",fontsize=10)

plt.subplot(4,4,5)
plt.scatter(train_data['pressure'] , train_data['power'],c='g')
plt.xlabel("pressure",fontsize=10)
plt.ylabel("Power",fontsize=10)

plt.subplot(4,4,6)
plt.scatter(train_data['dew_point'] , train_data['power'],c='g')
plt.xlabel("dew_point",fontsize=10)
plt.ylabel("Power",fontsize=10)


plt.subplot(4,4,7)
plt.scatter(train_data['wind_bearing'] , train_data['power'],c='g')
plt.xlabel("wind_bearing",fontsize=10)
plt.ylabel("Power",fontsize=10)


plt.subplot(4,4,8)
plt.scatter(train_data['wind_speed'] , train_data['power'],c='g')
plt.xlabel("wind_speed",fontsize=10)
plt.ylabel("Power",fontsize=10)

plt.subplot(4,4,9)
plt.scatter(train_data['ozone'] , train_data['power'],c='b')
plt.xlabel("ozone",fontsize=10)
plt.ylabel("Power",fontsize=10)


plt.subplot(4,4,10)
plt.scatter(train_data['precip_intensity'] , train_data['power'] , c='y')
plt.xlabel('precip_intensity',fontsize=1)
plt.ylabel("Power",fontsize=10)

plt.subplot(4,4,11)
plt.scatter(train_data['precip_probability'] , train_data['power'], c='c')
plt.xlabel("precip_probability",fontsize=10)
plt.ylabel("Power",fontsize=10)

plt.subplot(4,4,12)
plt.scatter(train_data['visibility'] , train_data['power'] ,c='r')
plt.xlabel("visibility",fontsize=10)
plt.ylabel("Power",fontsize=10)

plt.subplot(4,4,13)
plt.scatter(train_data['wind_gust'] , train_data['power'],c='g')
plt.xlabel("wind_gust ",fontsize=10)
plt.ylabel("Power",fontsize=10)


plt.subplot(4,4,14)
plt.scatter(train_data['uv_index'] , train_data['power'],c='g')
plt.xlabel("wind_speed",fontsize=10)
plt.ylabel("Power",fontsize=10)


plt.subplot(4,4,15)
plt.scatter(train_data['visibility'] , train_data['power'],c='g')
plt.xlabel("visibility",fontsize=10)
plt.ylabel("Power",fontsize=10)

plt.show()

# %% [markdown]
# if we observe above plot we can say some of colums are having less correlating and level of power being generated on different weather characterstics.

# %%
train_data.hist(figsize = (15,12))
plt.show()

# %% [markdown]
# If we obseve above histogram we can say that Maximum power is generated on sunlight light hours, Exposed hours, exposed duration.

# %% [markdown]
# # Encoding of categorical columns

# %%
ClimaticConditions = pd.get_dummies(train_data['icon'],drop_first=True)
train_data['icon'] = pd.factorize(train_data['icon'])[0]

# %%
train_data = pd.concat([train_data , ClimaticConditions ], axis=1)

# %%
#ClimaticConditions_forecast = pd.get_dummies(Forecast_weather['icon'],drop_first=True)
#Forecast_weather['icon'] = pd.factorize(Forecast_weather['icon'])[0]

# %%
#Forecast_weather = pd.concat([Forecast_weather , ClimaticConditions ], axis=1)

# %%
Forecast_weather.shape
# Out:
# (648, 19)

# %%
train_data.columns
# Out:
# Index(['power', 'cloud_cover', 'temperature', 'humidity', 'dew_point',
#        'wind_bearing', 'wind_speed', 'wind_gust', 'pressure', 'uv_index',
#        'ozone', 'precip_intensity', 'precip_probability', 'visibility', 'icon',
#        'dtUTC_hour', 'SR_hour', 'SS_hour', 'sunlight_hours',
#        'exposure_duration', 'clear-night', 'cloudy', 'fog',
#        'partly-cloudy-day', 'partly-cloudy-night', 'rain', 'wind'],
#       dtype='object')

# %%
#train_data.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
  train_data.shape
# Out:
# (13482, 27)

# %% [markdown]
# ### Dropping the column for which dummy variables were created

# %%
train_data.drop(['icon'], axis=1, inplace=True)

# %%
train_data.columns
# Out:
# Index(['power', 'cloud_cover', 'temperature', 'humidity', 'dew_point',
#        'wind_bearing', 'wind_speed', 'wind_gust', 'pressure', 'uv_index',
#        'ozone', 'precip_intensity', 'precip_probability', 'visibility',
#        'dtUTC_hour', 'SR_hour', 'SS_hour', 'sunlight_hours',
#        'exposure_duration', 'clear-night', 'cloudy', 'fog',
#        'partly-cloudy-day', 'partly-cloudy-night', 'rain', 'wind'],
#       dtype='object')

# %% [markdown]
# ## Scaling the features

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()

numericals = ['power','cloud_cover','temperature','humidity','dew_point','wind_bearing','wind_speed','wind_gust',\
           'pressure','uv_index','ozone','precip_intensity','precip_probability','visibility','dtUTC_hour', 'SR_hour', 'SS_hour', 'sunlight_hours','exposure_duration','sunlight_hours']

train_data[numericals] = scaler.fit_transform(train_data[numericals])

# %%
train_data.describe()
# Out:
#               power   cloud_cover   temperature      humidity     dew_point  \
# count  1.348200e+04  1.348200e+04  1.348200e+04  1.348200e+04  1.348200e+04
# mean   1.254069e-15  3.004664e-14 -3.121829e-15  1.235921e-14 -1.246823e-15
# std    1.000037e+00  1.000037e+00  1.000037e+00  1.000037e+00  1.000037e+00
# min   -6.307564e-01 -5.522680e+00 -2.196150e+00 -1.077461e+00 -3.564514e+00
# 25%   -6.307564e-01  1.809371e-01 -8.415144e-01 -1.077461e+00 -6.559904e-01
# 50%   -6.307564e-01  1.809371e-01  6.157586e-02  9.281074e-01 -1.305656e-01
# 75%    4.780241e-01  1.811653e-01  7.388936e-01  9.281074e-01  8.419650e-01
# max    2.687372e+00  1.815075e-01  2.545074e+00  9.281074e-01  1.811748e+00
#
#        wind_bearing    wind_speed     wind_gust      pressure      uv_index  \
# count  1.348200e+04  1.348200e+04  1.348200e+04  1.348200e+04  1.348200e+04
# mean  -1.094453e-15  1.184658e-15 -1.340070e-14  8.831300e-15  5.474829e-14
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(train_data.corr(),cmap='YlGnBu',annot=True)
plt.show()

# %% [markdown]
# ## Splitting into X and Y variables

# %%
Y = train_data.pop('power')
X = train_data

# %%
print('shape of X is :',X.shape)
print('shape of Y is :',Y.shape)
# Out:
# shape of X is : (13482, 25)
# shape of Y is : (13482,)

# %%
## Split into train and test
from sklearn.model_selection import train_test_split,cross_val_score
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
print('shape of X_train is :',X_train.shape)
print('shape of Y_train is :',Y_train.shape)
print('shape of X_test is :',X_test.shape)
print('shape of Y_test is :',Y_test.shape)
# Out:
# shape of X_train is : (10785, 25)
# shape of Y_train is : (10785,)
# shape of X_test is : (2697, 25)
# shape of Y_test is : (2697,)

# %% [markdown]
# ## Model  Building and Evaluation

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
 # create regressor object 
RF = RandomForestRegressor(n_estimators = 100, random_state = 0) 
  
# fit the regressor with x and y data 
RF.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
from sklearn import metrics
from sklearn.metrics import r2_score
## predictions
y_train_pred=RF.predict(X_train)
print('Variance for train data: ',r2_score(y_true=Y_train, y_pred=y_train_pred))
y_test_pred=RF.predict(X_test)
print('Variance for test data: ',r2_score(y_true=Y_test, y_pred=y_test_pred))
# Out:
# Variance for train data:  0.9766744030532682
# Variance for test data:  0.8474238903554775

# %%
from sklearn.metrics import mean_squared_error

print('RMS for train data: ',np.sqrt(mean_squared_error(y_true = Y_train , y_pred = y_train_pred)))
print('RMS for test data ',np.sqrt(mean_squared_error(y_true = Y_test , y_pred = y_test_pred)))
# Out:
# RMS for train data:  0.15272633769462124
# RMS for test data  0.390614588208315

# %%
print('MAE train:', metrics.mean_absolute_error(y_true = Y_train , y_pred = y_train_pred))
print('MAE test:', metrics.mean_absolute_error(y_true = Y_test , y_pred = y_test_pred))
# Out:
# MAE train: 0.06804250041297881
# MAE test: 0.1761539476417963

# %%
print('MSE train:', metrics.mean_squared_error(y_true = Y_train , y_pred = y_train_pred))
print('MSE test:', metrics.mean_squared_error(y_true = Y_test , y_pred = y_test_pred))
# Out:
# MSE train: 0.023325334225611487
# MSE test: 0.15257975652115152

# %% [raw]
# from sklearn.metrics import accuracy_score, precision_score, recall_score
# print("Accuracy is {0:.2f}".format(accuracy_score(Y_test, y_test_pred)))
# print("Precision is {0:.2f}".format(precision_score(Y_test, y_test_pred)))
# print("Recall is {0:.2f}".format(recall_score(Y_test, y_test_pred)))

# %% [markdown]
# To do acurracy, precision and recall it is saying continious is not supported

# %%
#Determining which features are most important,
# listing down the top most important features
features = X_train.columns
import_features = RF.feature_importances_
top_features = pd.DataFrame([f for f in zip (features, import_features)], columns = ["Feature","Importance"]).nlargest(10,"Importance")
top_features.sort_values(by = "Importance", inplace = True)
plt.figure(figsize=(10,6))
plt.barh(range(len(top_features)), top_features.Importance, align = 'center', alpha = 0.9)
plt.yticks(range(len(top_features)),top_features.Feature)
plt.xlabel('Importance')
plt.title('Top Features from Random Forest')
plt.show()

# %% [markdown]
# For Business Analysis it will be easy for us to analyze which features showing impact on our business problem.

# %% [markdown]
# # Perform Analysis of Forecast Data

# %%
Forecast_weather.shape
# Out:
# (648, 19)

# %%
Forecast_weather.icon.value_counts()
# Out:
# clear-night            265
# clear-day              225
# partly-cloudy-day       64
# partly-cloudy-night     64
# cloudy                  30
# Name: icon, dtype: int64

# %% [markdown]
# # Encoding categorical features

# %%
ClimateCond = pd.get_dummies(Forecast_weather['icon'],drop_first=True)

# %%
Forecast_weather = pd.concat([Forecast_weather , ClimateCond ], axis=1)

# %%
Forecast_weather.drop(['icon'], axis=1, inplace=True)

# %%
Forecast_weather['cloud_cover'].unique()
# Out:
# array([0.35, 0.43, 0.48, 0.49, 0.51, 0.59, 0.66, 0.69, 0.77, 0.83, 0.78,
#        0.7 , 0.61, 0.55, 0.24, 0.09, 0.06, 0.03, 0.  , 0.1 , 0.21, 0.23,
#        0.2 , 0.16, 0.07, 0.04, 0.01, 0.14, 0.27, 0.45, 0.47, 0.53, 0.44,
#        0.73, 0.75, 0.68, 0.62, 0.58, 0.31, 0.02, 0.15, 0.33, 0.91, 1.  ,
#        0.87, 0.12, 0.22, 0.17, 0.74, 0.86, 0.81, 0.6 , 0.39, 0.19, 0.25,
#        0.41, 0.54, 0.65, 0.72, 0.76, 0.84, 0.88, 0.95, 0.99, 0.98, 0.97,
#        0.96, 0.9 , 0.92, 0.64, 0.67, 0.63, 0.52, 0.4 , 0.28, 0.05, 0.08,
#        0.42, 0.32, 0.11, 0.94, 0.8 , 0.34, 0.18, 0.36, 0.13])

# %% [markdown]
# # Scaling the Numerical Values

# %%
scaler= StandardScaler()

numericals = ['cloud_cover', 'apparent_temperature', 'humidity', 'dew_point',
       'wind_bearing', 'wind_speed', 'wind_gust', 'pressure', 'uv_index',
       'ozone', 'precip_intensity', 'precip_probability', 'visibility',
       'dtUTC_hour', 'SR_hour', 'SS_hour', 'sunlight_hours',
       'exposure_duration']

Forecast_weather[numericals] = scaler.fit_transform(Forecast_weather[numericals])

# %%
Forecast_weather.columns
# Out:
# Index(['cloud_cover', 'apparent_temperature', 'humidity', 'dew_point',
#        'wind_bearing', 'wind_speed', 'wind_gust', 'pressure', 'uv_index',
#        'ozone', 'precip_intensity', 'precip_probability', 'visibility',
#        'dtUTC_hour', 'SR_hour', 'SS_hour', 'sunlight_hours',
#        'exposure_duration', 'clear-night', 'cloudy', 'partly-cloudy-day',
#        'partly-cloudy-night'],
#       dtype='object')

# %%
Forecast_weather.shape
# Out:
# (648, 22)

# %%
X_train.shape
# Out:
# (10785, 25)

# %%
test_forecast = Forecast_weather

# %%
scaler= StandardScaler()

Forecast_num = ['cloudy','cloud_cover','apparent_temperature','humidity','dew_point','wind_bearing','wind_speed','wind_gust',\
           'pressure','uv_index','ozone','precip_intensity','precip_probability','visibility','dtUTC_hour', 'SR_hour', 'SS_hour', 'sunlight_hours','exposure_duration']

test_forecast[Forecast_num] = scaler.fit_transform(test_forecast[Forecast_num])

# %%
test_forecast.shape
# Out:
# (648, 22)

# %%
difference = set( X_train.columns ) - set( test_forecast.columns )

# %%
# Add a missing column in test set with default value equal to 0
for i in difference:
    Forecast_weather[i] = 0
# Ensure the order of column in the test set is in the same order than in train set
test_forecast = test_forecast[X_train.columns]

# %%
test_forecast.shape
# Out:
# (648, 25)

# %%
test_forecast.dtypes
# Out:
# cloud_cover            float64
# temperature              int64
# humidity               float64
# dew_point              float64
# wind_bearing           float64
# wind_speed             float64
# wind_gust              float64
# pressure               float64
# uv_index               float64
# ozone                  float64
# precip_intensity       float64
# precip_probability     float64
# visibility             float64
# dtUTC_hour             float64
# SR_hour                float64
# SS_hour                float64
# sunlight_hours         float64
# exposure_duration      float64
# clear-night              uint8
# cloudy                 float64
# fog                      int64
# partly-cloudy-day        uint8
# partly-cloudy-night      uint8
# rain                     int64
# wind                     int64
# dtype: object

# %%
#RF.fit(Forecast_weather,0)   
Y_prediction=RF.predict(test_forecast)

# %%
print(Y_prediction)
# Out:
# [-6.30756372e-01 -6.30756372e-01 -6.30756372e-01 -6.30756372e-01
#  -6.30756372e-01 -6.30756372e-01 -6.27080970e-01 -4.70989322e-01
#  -1.47225429e-01 -1.55479683e-01  1.01921646e-01  4.12606036e-01
#   2.87642372e-01  1.37012494e-01  3.26347024e-01  2.01547623e-01
#   5.46136802e-02 -4.20580877e-01 -6.30756372e-01 -6.30756372e-01
#  -6.30756372e-01 -6.30756372e-01 -6.30756372e-01 -6.30756372e-01
#  -6.30756372e-01 -6.30756372e-01 -6.30756372e-01 -6.30756372e-01
#  -6.30756372e-01 -6.30756372e-01 -5.44168832e-01 -4.98749899e-01
#  -1.98331994e-01 -5.97344375e-02  3.31295470e-01  2.43373286e-01
#   1.98816738e-01  9.55974911e-02  7.07936616e-02  2.44666863e-01
#   6.75132384e-03 -5.39774776e-01 -6.30756372e-01 -6.30756372e-01
#  -6.30756372e-01 -6.30756372e-01 -6.30756372e-01 -6.30756372e-01
#  -6.30756372e-01 -6.30756372e-01 -6.30756372e-01 -6.30756372e-01
#  -6.30756372e-01 -6.30756372e-01 -6.27080970e-01 -4.77313477e-01
# ...

# %%
Y_prediction.shape
# Out:
# (648,)

# %%
test_forecast['power_predicted'] = Y_prediction

# %%
test_forecast.columns
# Out:
# Index(['cloud_cover', 'temperature', 'humidity', 'dew_point', 'wind_bearing',
#        'wind_speed', 'wind_gust', 'pressure', 'uv_index', 'ozone',
#        'precip_intensity', 'precip_probability', 'visibility', 'dtUTC_hour',
#        'SR_hour', 'SS_hour', 'sunlight_hours', 'exposure_duration',
#        'clear-night', 'cloudy', 'fog', 'partly-cloudy-day',
#        'partly-cloudy-night', 'rain', 'wind', 'power_predicted'],
#       dtype='object')

# %%
weatherpred_num = ['cloud_cover', 'apparent_temperature', 'humidity', 'dew_point',
       'wind_bearing', 'wind_speed', 'wind_gust', 'pressure', 'uv_index',
       'ozone', 'precip_intensity', 'precip_probability', 'visibility',
       'dtUTC_hour', 'SR_hour', 'SS_hour', 'sunlight_hours',
       'exposure_duration', 'clear-night', 'cloudy', 'fog',
       'partly-cloudy-day', 'partly-cloudy-night', 'rain', 'wind',
       'power_predicted']

# %%
test_forecast['power_predicted'].values
# Out:
# array([-6.30756372e-01, -6.30756372e-01, -6.30756372e-01, -6.30756372e-01,
#        -6.30756372e-01, -6.30756372e-01, -6.27080970e-01, -4.70989322e-01,
#        -1.47225429e-01, -1.55479683e-01,  1.01921646e-01,  4.12606036e-01,
#         2.87642372e-01,  1.37012494e-01,  3.26347024e-01,  2.01547623e-01,
#         5.46136802e-02, -4.20580877e-01, -6.30756372e-01, -6.30756372e-01,
#        -6.30756372e-01, -6.30756372e-01, -6.30756372e-01, -6.30756372e-01,
#        -6.30756372e-01, -6.30756372e-01, -6.30756372e-01, -6.30756372e-01,
#        -6.30756372e-01, -6.30756372e-01, -5.44168832e-01, -4.98749899e-01,
#        -1.98331994e-01, -5.97344375e-02,  3.31295470e-01,  2.43373286e-01,
#         1.98816738e-01,  9.55974911e-02,  7.07936616e-02,  2.44666863e-01,
#         6.75132384e-03, -5.39774776e-01, -6.30756372e-01, -6.30756372e-01,
#        -6.30756372e-01, -6.30756372e-01, -6.30756372e-01, -6.30756372e-01,
# ...

# %% [markdown]
# for Easy understand lets go with graph

# %%
sns.distplot(test_forecast['power_predicted'], hist= True)

# %%
plt.show()
